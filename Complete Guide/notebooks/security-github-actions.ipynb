# %% [markdown]
# ``` Security ```
#
#
# - Script injections
#     -
# - Malicious third party actions
#     - Always inspect the code for third party actions
#     - Check the provider of the action
# - Permission issues
#     - Consider each action and how to control what each actions can do

# %% [markdown]
# ```Script Injection Examples```
#
# - Avoid using the on: issues: types: - opened
#     - When an issue is created, the title can close commands and insert scripts. use an action so that it runs on github and will not reach a shell
#     - don't run scripts in line of run
#     - store it in a new variable
#     - env: TITLE: ${{github.event.issues.title}} <- Sanitize the input

# %% [markdown]
# ``` Actions ```
# - Build by verified creator for each action, check for the checkmark in each creator
# - Read the code of each action
# - Github does not verify third party actions - they are all open source

# %% [markdown]
# ``` Permissions ```
# - Set a restrictive permission for each workflow
# - Permission is added on job level or workflow level
# - permissions: issues: read | write
# - by default - all jobs have full permissions
# - Each request github adds a token that sets the permission for the curl command
# - Some restrictions can also be added on the settings of the repo
# - first time contributors : workflows does not run if the contributor is from a fork
